# %% [markdown]
# <a href="https://colab.research.google.com/github/Frixon21/CPSC-483-Introduction-to-Machine-Learning/blob/main/02_end_to_end_machine_learning_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Chapter 2 – End-to-end Machine Learning project**

# %% [markdown]
# ## Download the Data

# %%
from packaging import version
import sklearn
from pathlib import Path
import pandas as pd
import tarfile
import urllib.request

def load_housing_data():
    tarball_path = Path("datasets/housing.tgz")
    if not tarball_path.is_file():
        Path("datasets").mkdir(parents=True, exist_ok=True)
        url = "https://github.com/ageron/data/raw/main/housing.tgz"
        urllib.request.urlretrieve(url, tarball_path)
    with tarfile.open(tarball_path) as housing_tarball:
            housing_tarball.extractall(path="datasets")
    return pd.read_csv(Path("datasets/housing/housing.csv"))

housing = load_housing_data()

# %% [markdown]
# ##	What is the target variable?

# %%
housing['median_house_value']
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20640, dtype: float64

# %% [markdown]
# # Plot a scatter plot of median_income and median_house_value [show plot]

# %%
import matplotlib.pyplot as plt

housing.plot(kind="scatter", x="median_income", y="median_house_value",alpha=0.1)
plt.show()

# %% [markdown]
# # Remove all rows where median_house_value >= 500,000

# %%
# !git reset --hard HEAD~1
# Out:
# fatal: not a git repository (or any of the parent directories): .git
